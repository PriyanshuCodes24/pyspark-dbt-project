# %%
df  = spark.read.format('csv')\
        .option('header', True)\
        .option('inferSchema', True)\
        .load('/Volumes/pyspark_dbt/source/raw_data/customers/')

# %%
df.limit(10).display()
